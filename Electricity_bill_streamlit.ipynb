# %%
import streamlit as st

st.title("⚡ Electricity Bill Calculator")

units = st.number_input("Enter Units Consumed", min_value=0, step=1)

bill = 0

if units <= 100:
    bill = units * 5
elif units <= 200:
    bill = (100 * 5) + (units - 100) * 7
else:
    bill = (100 * 5) + (100 * 7) + (units - 200) * 10

gst = bill * 0.18
total = bill + gst

st.subheader("🧾 Bill Summary")
st.write(f"Units Consumed: **{units}**")
st.write(f"Bill Amount: **₹{bill:.2f}**")
st.write(f"GST (18%): **₹{gst:.2f}**")
st.write(f"Total Payable: **₹{total:.2f}**")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import streamlit as st
#       3 st.title("⚡ Electricity Bill Calculator")
#       5 units = st.number_input("Enter Units Consumed", min_value=0, step=1)
#
# File ~\streamlit.py:3
#       1 import streamlit as st
# ----> 3 st.title("⚡ Electricity Bill Calculator")
#       5 units = st.number_input("Enter Units Consumed", min_value=0, step=1)
#       7 bill = 0
#
# AttributeError: module 'streamlit' has no attribute 'title' (consider renaming 'C:\Users\us\streamlit.py' if it has the same name as a library you intended to import)
